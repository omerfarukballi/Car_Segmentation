# %% [markdown]
# ![logo.png](data:image/png;base64,...)

# %% [markdown]
# ### Automated high-quality background removal framework for an image using neural networks
#
#
#
# - 🏢 [Project at GitHub](https://github.com/OPHoperHPO/image-background-remove-tool) 🏢
# - 🔗 [Author at GitHub](https://github.com/OPHoperHPO) 🔗
#
# > Please rate our repository with ⭐ if you like our work! Thanks! 😀

# %% [markdown]
# This notebook supports **Google Colab GPU runtime**.
#
# > **Enabling and testing the GPU** \
# > Navigate to `Edit → Notebook Settings`. \
# > Select `GPU` from the `Hardware Accelerator` drop-down.

# %% [markdown]
# # Install CarveKit

# %%
#@title Install colab-ready python package (Click the arrow on the left)
# %cd /content
# !pip install carvekit_colab
# Out:
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting carvekit_colab
#   Downloading carvekit_colab-4.1.0-py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 1.8 MB/s
# Collecting aiofiles
#   Downloading aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (4.64.1)
# Collecting fastapi
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (57.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (7.1.2)
# Collecting starlette
#   Downloading starlette-0.23.1-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.5 MB/s
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (1.10.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (0.14.0+cu116)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (2.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (1.21.6)
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.2 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (1.13.0+cu116)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from carvekit_colab) (4.6.0.66)
# Collecting starlette
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.6 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.8/dist-packages (from starlette->carvekit_colab) (4.4.0)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 5.7 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.8/dist-packages (from anyio<5,>=3.4.0->starlette->carvekit_colab) (2.10)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from python-multipart->carvekit_colab) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->carvekit_colab) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->carvekit_colab) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->carvekit_colab) (3.0.4)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.0 MB/s
# Building wheels for collected packages: python-multipart
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=a866e361a396add7f6ad11009b7868e11f74f81b883dd8b392e6b62556f649ee
#   Stored in directory: /root/.cache/pip/wheels/9e/fc/1c/cf980e6413d3ee8e70cd8f39e2366b0f487e3e221aeb452eb0
# Successfully built python-multipart
# Installing collected packages: sniffio, anyio, starlette, h11, uvicorn, python-multipart, loguru, fastapi, aiofiles, carvekit-colab
# Successfully installed aiofiles-22.1.0 anyio-3.6.2 carvekit-colab-4.1.0 fastapi-0.88.0 h11-0.14.0 loguru-0.6.0 python-multipart-0.0.5 sniffio-1.3.0 starlette-0.22.0 uvicorn-0.20.0

# %%
#@title Download all models
from carvekit.ml.files.models_loc import download_all

download_all();

# %% [markdown]
# # Remove background using CarveKit

# %%
#@title Upload images from your computer
#@markdown Description of parameters
#@markdown - `SHOW_FULLSIZE`  - Shows image in full size (may take a long time to load)
#@markdown - `PREPROCESSING_METHOD`  - Preprocessing method
#@markdown - `SEGMENTATION_NETWORK`  - Segmentation network. Use `u2net` for hairs-like objects and `tracer_b7` for objects
#@markdown - `POSTPROCESSING_METHOD`  - Postprocessing method
#@markdown - `SEGMENTATION_MASK_SIZE` - Segmentation mask size. Use 640 for Tracer B7 and 320 for U2Net
#@markdown - `TRIMAP_DILATION`  - The size of the offset radius from the object mask in pixels when forming an unknown area
#@markdown - `TRIMAP_EROSION`  - The number of iterations of erosion that the object's mask will be subjected to before forming an unknown area
#@markdown > Look README.md and code for more details on networks and methods


import torch
from IPython import display
from google.colab import files
from carvekit.web.schemas.config import MLConfig
from carvekit.web.utils.init_utils import init_interface

SHOW_FULLSIZE = False #@param {type:"boolean"}
PREPROCESSING_METHOD = "none" #@param ["stub", "none"]
SEGMENTATION_NETWORK = "tracer_b7" #@param ["u2net", "deeplabv3", "basnet", "tracer_b7"]
POSTPROCESSING_METHOD = "fba" #@param ["fba", "none"] 
SEGMENTATION_MASK_SIZE = 640 #@param ["640", "320"] {type:"raw", allow-input: true}
TRIMAP_DILATION = 30 #@param {type:"integer"}
TRIMAP_EROSION = 5 #@param {type:"integer"}
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'


config = MLConfig(segmentation_network=SEGMENTATION_NETWORK,
                  preprocessing_method=PREPROCESSING_METHOD,
                  postprocessing_method=POSTPROCESSING_METHOD,
                  seg_mask_size=SEGMENTATION_MASK_SIZE,
                  trimap_dilation=TRIMAP_DILATION,
                  trimap_erosion=TRIMAP_EROSION,
                  device=DEVICE)


interface = init_interface(config)




uploaded = files.upload().keys()
display.clear_output()
images = interface(uploaded)
for im in enumerate(images):
  if not SHOW_FULLSIZE:
    im[1].thumbnail((768, 768), resample=3)
  display.display(im[1])
# Out:
# <PIL.Image.Image image mode=RGBA size=768x432 at 0x7FE6D76DC6A0>
